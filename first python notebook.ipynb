# %% [markdown]
# # First Python Notebook
# Hello world!

# %%
2+2
# Out:
# 4

# %% [markdown]
# ### Learning some basics

# %%
number = 2
number+3
# Out:
# 5

# %% [markdown]
# ###  Imports and allows pandas to be expressed with 'pd'

# %%
import pandas as pd

# %% [markdown]
# ### Importing matplotlib, which makes quick charts

# %%
# %matplotlib inline

# %% [markdown]
# ### Turns a list of numbers into a 'series', which can then be used to find a lot of neato stuff

# %%
my_list = [2, 4, 6, 8]

# %%
my_series = pd.Series(my_list)

# %%
my_series.sum()
# Out:
# 20

# %%
my_series.max()
# Out:
# 8

# %%
my_series.min()
# Out:
# 2

# %%
my_series.describe()
# Out:
# count    4.000000
# mean     5.000000
# std      2.581989
# min      2.000000
# 25%      3.500000
# 50%      5.000000
# 75%      6.500000
# max      8.000000
# dtype: float64

# %% [markdown]
# ### Import a .csv using pandas (pandas.read) - csv is committees for or against props in Cali Nov '16 ballot

# %%
pd.read_csv("http://www.firstpythonnotebook.org/_static/committees.csv")
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 0    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 5    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 6    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 7    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 8    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 9    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 10   ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 11   ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# ...

# %% [markdown]
# ### Saving csv into a 'variable' - or a named shortcut

# %%
props = pd.read_csv("http://www.firstpythonnotebook.org/_static/committees.csv")

# %%
props.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4  ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
#
#    ccdc_prop_id                                          prop_name  \
# 0            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4            71  PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                382                 1374469
# ...

# %%
props.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
# ocd_prop_id               102 non-null object
# calaccess_prop_id         102 non-null int64
# ccdc_prop_id              102 non-null int64
# prop_name                 102 non-null object
# ccdc_committee_id         102 non-null int64
# calaccess_committee_id    102 non-null int64
# committee_name            102 non-null object
# committee_position        102 non-null object
# dtypes: int64(4), object(4)
# memory usage: 6.4+ KB

# %% [markdown]
# ### Import csv with contributions to props in Cali Nov '16 ballot & turning it into a variable

# %%
contrib = pd.read_csv("http://www.firstpythonnotebook.org/_static/contributions.csv")

# %%
contrib.head()
# Out:
#    calaccess_committee_id                              committee_name  \
# 0                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 1                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 2                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 3                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 4                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
#
#    calaccess_filing_id date_received contributor_lastname  \
# 0              2083796    2016-09-18              BERGMAN
# 1              2083796    2016-09-18                KAHLE
# 2              2083796    2016-07-15             MCDEVITT
# 3              2083796    2016-08-10      WARREN-SAMARIPA
# 4              2083796    2016-07-26      WARREN-SAMARIPA
#
#   contributor_firstname contributor_city contributor_state contributor_zip  \
# 0              GRETCHEN    SPRING VALLEY                CA           91978
# ...

# %%
contrib.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56379 entries, 0 to 56378
# Data columns (total 13 columns):
# calaccess_committee_id          56379 non-null int64
# committee_name                  56379 non-null object
# calaccess_filing_id             56379 non-null int64
# date_received                   56379 non-null object
# contributor_lastname            56375 non-null object
# contributor_firstname           53411 non-null object
# contributor_city                56369 non-null object
# contributor_state               56363 non-null object
# contributor_zip                 56366 non-null object
# contributor_employer            48572 non-null object
# contributor_occupation          53273 non-null object
# contributor_is_self_employed    56379 non-null bool
# amount                          56379 non-null float64
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 5.2+ MB

# %% [markdown]
# ### Listing prop names in a series

# %%
props.prop_name
# Out:
# 0      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 5      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 6      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 7      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 8      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 9      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 10     PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 11     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 12     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 13     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 14     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 15     PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...
# ...

# %% [markdown]
# ### Which props had the most committees?

# %%
props.prop_name.value_counts()
# Out:
# PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE CRIMINAL PROCEEDINGS AND SENTENCING. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.                           13
# PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTHCARE, TOBACCO USE PREVENTION, RESEARCH, AND LAW ENFORCEMENT. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.    12
# PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.                                                                                                   11
# PROPOSITION 066- DEATH PENALTY. PROCEDURES. INITIATIVE STATUTE.                                                                                                 9
# PROPOSITION 055 - TAX EXTENSION TO FUND EDUCATION AND HEALTHCARE. INITIATIVE CONSTITUTIONAL AMENDMENT.                                                          8
# PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON SINGLE-USE PLASTIC BAGS.                                                                                         7
# ...

# %% [markdown]
# ### Que feo ^, let's pretty it up! .reset_index() does that job!

# %%
props.prop_name.value_counts().reset_index()
# Out:
#                                                 index  prop_name
# 0   PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...         13
# 1   PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...         12
# 2   PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...         11
# 3   PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...          9
# 4   PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...          8
# 5   PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...          7
# 6   PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...          7
# 7   PROPOSITION 059- SB 254 (CHAPTER 20, STATUTES ...          6
# 8   PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...          4
# 9   PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...          4
# 10  PROPOSITION 058 - SB 1174 (CHAPTER 753, STATUT...          4
# 11  PROPOSITION 063- FIREARMS. AMMUNITION SALES. I...          4
# 12  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...          4
# ...

# %% [markdown]
# ### Filtering out prop 064

# %%
props.prop_name == 'PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 72     False
# 73     False
# 74      True
# 75      True
# 76      True
# 77      True
# 78      True
# 79      True
# 80      True
# 81      True
# 82      True
# 83      True
# 84      True
# 85     False
# 86     False
# 87     False
# 88     False
# 89     False
# 90     False
# 91     False
# 92     False
# 93     False
# 94     False
# 95     False
# 96     False
# 97     False
# 98     False
# 99     False
# 100    False
# 101    False
# Name: prop_name, Length: 102, dtype: bool

# %%
props[props.prop_name == 'PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.']
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 74  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 75  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 76  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 77  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 78  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 79  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 80  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 81  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 82  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 83  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 84  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#     ccdc_prop_id                                          prop_name  \
# ...

# %% [markdown]
# ### Turning prop 64 into it's own 'variable'

# %%
prop = props[props.prop_name == 'PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.']

# %%
prop.head()
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 74  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 75  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 76  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 77  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 78  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#     ccdc_prop_id                                          prop_name  \
# 74            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 75            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 76            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 77            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 78            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
#
#     ccdc_committee_id  calaccess_committee_id  \
# 74                456                 1381808
# ...

# %%
prop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11 entries, 74 to 84
# Data columns (total 8 columns):
# ocd_prop_id               11 non-null object
# calaccess_prop_id         11 non-null int64
# ccdc_prop_id              11 non-null int64
# prop_name                 11 non-null object
# ccdc_committee_id         11 non-null int64
# calaccess_committee_id    11 non-null int64
# committee_name            11 non-null object
# committee_position        11 non-null object
# dtypes: int64(4), object(4)
# memory usage: 792.0+ bytes

# %%
contrib.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56379 entries, 0 to 56378
# Data columns (total 13 columns):
# calaccess_committee_id          56379 non-null int64
# committee_name                  56379 non-null object
# calaccess_filing_id             56379 non-null int64
# date_received                   56379 non-null object
# contributor_lastname            56375 non-null object
# contributor_firstname           53411 non-null object
# contributor_city                56369 non-null object
# contributor_state               56363 non-null object
# contributor_zip                 56366 non-null object
# contributor_employer            48572 non-null object
# contributor_occupation          53273 non-null object
# contributor_is_self_employed    56379 non-null bool
# amount                          56379 non-null float64
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 5.2+ MB

# %%
props.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
# ocd_prop_id               102 non-null object
# calaccess_prop_id         102 non-null int64
# ccdc_prop_id              102 non-null int64
# prop_name                 102 non-null object
# ccdc_committee_id         102 non-null int64
# calaccess_committee_id    102 non-null int64
# committee_name            102 non-null object
# committee_position        102 non-null object
# dtypes: int64(4), object(4)
# memory usage: 6.4+ KB

# %% [markdown]
# ### Now let's merge calaccess_committee_id from both the contributors and the committee's!

# %%
merged = pd.merge(props, contrib, on="calaccess_committee_id")

# %%
merged.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
#
#    ccdc_prop_id                                          prop_name  \
# 0            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                382                 1374469
# ...

# %% [markdown]
# ### Now we have all disclosed contribs to prop 64 from committees

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90264 entries, 0 to 90263
# Data columns (total 20 columns):
# ocd_prop_id                     90264 non-null object
# calaccess_prop_id               90264 non-null int64
# ccdc_prop_id                    90264 non-null int64
# prop_name                       90264 non-null object
# ccdc_committee_id               90264 non-null int64
# calaccess_committee_id          90264 non-null int64
# committee_name_x                90264 non-null object
# committee_position              90264 non-null object
# committee_name_y                90264 non-null object
# calaccess_filing_id             90264 non-null int64
# date_received                   90264 non-null object
# contributor_lastname            90256 non-null object
# contributor_firstname           86685 non-null object
# contributor_city                90251 non-null object
# contributor_state               90244 non-null object
# ...

# %%
merged.amount
# Out:
# 0         50000.0
# 1         55000.0
# 2        140000.0
# 3        140000.0
# 4         50000.0
# 5         50000.0
# 6        125000.0
# 7         75000.0
# 8        112500.0
# 9         75000.0
# 10       100000.0
# 11       100000.0
# 12       100000.0
# 13       100000.0
# 14       100000.0
# 15       100000.0
# 16       100000.0
# 17       100000.0
# 18        37500.0
# 19          100.0
# 20        10000.0
# 21         5000.0
# 22       112500.0
# 23        10000.0
# 24       112500.0
# 25          100.0
# 26          100.0
# 27          100.0
# 28          100.0
# 29          100.0
#            ...
# 90234       100.0
# 90235       100.0
# 90236       100.0
# 90237      5000.0
# 90238      1000.0
# 90239    100000.0
# 90240    100000.0
# 90241      5000.0
# 90242       100.0
# 90243       100.0
# 90244       100.0
# 90245       100.0
# 90246       100.0
# 90247       100.0
# 90248       100.0
# 90249       100.0
# 90250       100.0
# 90251       100.0
# 90252       100.0
# ...

# %%
merged.amount.sum()
# Out:
# 466851993.3900001

# %% [markdown]
# ### Ok but how much contribs from each side?

# %%
merged.committee_position.value_counts()
# Out:
# SUPPORT    50158
# OPPOSE     40106
# Name: committee_position, dtype: int64

# %% [markdown]
# ### Now we are turning the supports and opposition into their own variable!

# %%
support = merged[merged.committee_position == 'SUPPORT']

# %%
oppose = merged[merged.committee_position == "OPPOSE"]

# %% [markdown]
# ### Having fun with sorting!

# %%
oppose.amount.sum()
# Out:
# 226772758.05000007

# %%
support.amount.sum()
# Out:
# 240079235.34000006

# %%
support.amount.sum() / oppose.amount.sum ()
# Out:
# 1.0586775828120683

# %%
merged.sort_values("amount")
# Out:
#                                             ocd_prop_id  calaccess_prop_id  \
# 83297  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 864    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 74164  ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 865    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 79618  ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 77522  ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 75328  ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 75591  ocd-contest/e02dc48a-2ed3-4a87-859b-26c90f0539e7            1381803
# 2973   ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# 69856  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
# 69624  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
# ...

# %%
merged.sort_values("amount", ascending=False)
# Out:
#                                             ocd_prop_id  calaccess_prop_id  \
# 1863   ocd-contest/446ec3da-7de1-45f0-9f97-228e53c6a9f6            1382647
# 1865   ocd-contest/446ec3da-7de1-45f0-9f97-228e53c6a9f6            1382647
# 1972   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 1979   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 2026   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 1967   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 1851   ocd-contest/446ec3da-7de1-45f0-9f97-228e53c6a9f6            1382647
# 1547   ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 1973   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 1980   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 1968   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# ...

# %%
merged.sort_values("amount", ascending=False).head()
# Out:
#                                            ocd_prop_id  calaccess_prop_id  \
# 1863  ocd-contest/446ec3da-7de1-45f0-9f97-228e53c6a9f6            1382647
# 1865  ocd-contest/446ec3da-7de1-45f0-9f97-228e53c6a9f6            1382647
# 1972  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 1979  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 2026  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
#
#       ccdc_prop_id                                          prop_name  \
# 1863            74  PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...
# 1865            74  PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...
# 1972            75  PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...
# 1979            75  PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...
# 2026            75  PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...
#
#       ccdc_committee_id  calaccess_committee_id  \
# ...

# %%
support.sort_values("amount", ascending=False).head()
# Out:
#                                            ocd_prop_id  calaccess_prop_id  \
# 1863  ocd-contest/446ec3da-7de1-45f0-9f97-228e53c6a9f6            1382647
# 1865  ocd-contest/446ec3da-7de1-45f0-9f97-228e53c6a9f6            1382647
# 2026  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 1851  ocd-contest/446ec3da-7de1-45f0-9f97-228e53c6a9f6            1382647
# 1547  ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
#
#       ccdc_prop_id                                          prop_name  \
# 1863            74  PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...
# 1865            74  PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...
# 2026            75  PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...
# 1851            74  PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...
# 1547            71  PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
#
#       ccdc_committee_id  calaccess_committee_id  \
# ...

# %%
oppose.sort_values("amount", ascending=False).head()
# Out:
#                                            ocd_prop_id  calaccess_prop_id  \
# 1972  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 1979  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 1967  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 1973  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 1980  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
#
#       ccdc_prop_id                                          prop_name  \
# 1972            75  PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...
# 1979            75  PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...
# 1967            75  PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...
# 1973            75  PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...
# 1980            75  PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...
#
#       ccdc_committee_id  calaccess_committee_id  \
# ...

# %% [markdown]
# ### 'groupby' allows you to group by column, so lets see how much each committee raised!

# %%
merged.groupby("committee_name_x").amount.sum()
# Out:
# committee_name_x
# ADULT USE CAMPAIGN FOR PROPOSITION 64; THE                                                                                                                                                                1.708900e+04
# AMERICAN PROGRESSIVE BAG ALLIANCE, A PROJECT OF THE SOCIETY OF THE PLASTICS INDUSTRY (NON-PROFIT 501 (C) (6)), YES ON 65 AND NO ON 67                                                                     5.362826e+06
# CALIFORNIA CALLS ACTION FUND (NONPROFIT 501(C)(4))                                                                                                                                                        2.087600e+05
# CALIFORNIA CITIZENS AGAINST SPECIAL INTERESTS AND WASTEFUL TAXES, NO ON PROP. 56                                                                                                                          3.205000e+04
# ...

# %% [markdown]
# ### Ugly again :(

# %%
merged.groupby("committee_name_x").amount.sum().reset_index()
# Out:
#                                      committee_name_x        amount
# 0          ADULT USE CAMPAIGN FOR PROPOSITION 64; THE  1.708900e+04
# 1   AMERICAN PROGRESSIVE BAG ALLIANCE, A PROJECT O...  5.362826e+06
# 2   CALIFORNIA CALLS ACTION FUND (NONPROFIT 501(C)...  2.087600e+05
# 3   CALIFORNIA CITIZENS AGAINST SPECIAL INTERESTS ...  3.205000e+04
# 4   CALIFORNIA COMMON CAUSE -- YES ON 54 AND 59 (N...  1.007777e+05
# 5   CALIFORNIA CORRECTIONAL PEACE OFFICERS ASSOCIA...  1.668644e+07
# 6   CALIFORNIA GROCERS ASSOCIATION ISSUES COMMITTE...  2.000000e+05
# 7   CALIFORNIA KIDS CAMPAIGN, YES ON PROPS 55 & 56...  5.900000e+05
# 8   CALIFORNIA STATEWIDE LAW ENFORCEMENT ASSOCIATI...  4.980960e+05
# 9   CALIFORNIANS FOR HOSPITAL ACCOUNTABILITY AND Q...  3.526622e+06
# 10  CALIFORNIANS FOR RESPONSIBLE MARIJUANA REFORM,...  8.604700e+05
# 11  CALIFORNIANS FOR SENSIBLE REFORM, SPONSORED BY...  8.500000e+05
# 12  CALIFORNIANS TO MEND, NOT END, THE DEATH PENAL...  1.677570e+07
# ...

# %% [markdown]
# #### note to self, how do I fix the amount so it shows up the total and not using scientific notation?

# %%
merged.groupby("committee_name_x").amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#                                      committee_name_x        amount
# 34  NO ON PROP 61 - CALIFORNIANS AGAINST THE DECEP...  1.084172e+08
# 31  NO ON 56 - STOP THE SPECIAL INTEREST TAX GRAB....  5.465050e+07
# 53  YES ON 55 - CALIFORNIANS FOR BUDGET STABILITY,...  5.349475e+07
# 54  YES ON 56 - SAVES LIVES CALIFORNIA, A COALITIO...  2.926786e+07
# 20       FUND FOR POLICY REFORM (NONPROFIT 501(C)(4))  2.456000e+07
# 33  NO ON PROP 53 - CALIFORNIANS TO PROTECT LOCAL ...  1.883050e+07
# 64  YES ON PROP 61, CALIFORNIANS FOR LOWER DRUG PR...  1.874717e+07
# 12  CALIFORNIANS TO MEND, NOT END, THE DEATH PENAL...  1.677570e+07
# 5   CALIFORNIA CORRECTIONAL PEACE OFFICERS ASSOCIA...  1.668644e+07
# 60  YES ON 64, CALIFORNIANS TO CONTROL, REGULATE A...  1.573405e+07
# 59  YES ON 62, NO ON 66. REPLACE THE COSTLY, FAILE...  1.524336e+07
# 67  YES ON PROPOSITION 52 - A COALITION OF CALIFOR...  1.275652e+07
# 26  MILLION VOTER PROJECT ACTION FUND - YES ON 55,...  1.266000e+07
# ...

# %% [markdown]
# ### Committees are interesting, but who is donating?

# %%
merged.groupby(["contributor_firstname", "contributor_lastname"]).amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#       contributor_firstname               contributor_lastname      amount
# 36156             THOMAS F.                             STEYER  11500000.0
# 36094                THOMAS                             STEYER  10500000.0
# 33779                  SEAN     PARKER AND AFFILIATED ENTITIES   7250000.0
# 27738              NICHOLAS                            MCKEOWN   3000000.0
# 30160                  REED                           HASTINGS   2000000.0
# 8685                DEAN A.                         CORTOPASSI   2000000.0
# 33778                  SEAN                             PARKER   1900000.0
# 17540                  JOAN                         CORTOPASSI   1500000.0
# 20280                 JULIE                            SCHAUER   1364000.0
# 27740              NICHOLAS                           PRITZKER   1250000.0
# 7111                 DANIEL                              LEWIS   1250000.0
# ...

# %%
merged.groupby(["contributor_firstname", "contributor_lastname", "committee_position"]).amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#       contributor_firstname               contributor_lastname  \
# 64012             THOMAS F.                             STEYER
# 63895                THOMAS                             STEYER
# 59904                  SEAN     PARKER AND AFFILIATED ENTITIES
# 15504               DEAN A.                         CORTOPASSI
# 59903                  SEAN                             PARKER
# 63894                THOMAS                             STEYER
# 31185                  JOAN                         CORTOPASSI
# 49097              NICHOLAS                            MCKEOWN
# 49096              NICHOLAS                            MCKEOWN
# 36143                 JULIE                            SCHAUER
# 12649                DANIEL                              LEWIS
# 49099              NICHOLAS                           PRITZKER
# 39052               L. JOHN                         DOERR, III
# 25034                 HENRY                      VAN AMERINGEN
# ...

# %%
top_supporters = support.groupby(
["contributor_firstname", "contributor_lastname"]
).amount.sum().reset_index().sort_values("amount", ascending=False).head(10)

# %%
top_supporters.head(10)
# Out:
#       contributor_firstname            contributor_lastname      amount
# 33944             THOMAS F.                          STEYER  11400000.0
# 33885                THOMAS                          STEYER   8750000.0
# 31730                  SEAN  PARKER AND AFFILIATED ENTITIES   7250000.0
# 8208                DEAN A.                      CORTOPASSI   2000000.0
# 31729                  SEAN                          PARKER   1900000.0
# 26088              NICHOLAS                         MCKEOWN   1500000.0
# 16470                  JOAN                      CORTOPASSI   1500000.0
# 26089              NICHOLAS                        PRITZKER   1250000.0
# 6745                 DANIEL                           LEWIS   1250000.0
# 13221                 HENRY                   VAN AMERINGEN   1000000.0

# %%
top_opposition = oppose.groupby(
["contributor_firstname", "contributor_lastname"]
).amount.sum().reset_index().sort_values("amount", ascending=False).head(10)

# %%
top_opposition.head(10)
# Out:
#       contributor_firstname               contributor_lastname     amount
# 30009                THOMAS                             STEYER  1750000.0
# 23008              NICHOLAS                            MCKEOWN  1500000.0
# 17105                 JULIE                            SCHAUER  1364000.0
# 25036                  REED                           HASTINGS  1000000.0
# 18392               L. JOHN                         DOERR, III  1000000.0
# 18391               L. JOHN                              DOERR   500000.0
# 5                A. JERROLD  PERENCHIO AND AFFILIATED ENTITIES   500000.0
# 23742                  PAUL                             GRAHAM   500000.0
# 11855              HENRY T.                       NICHOLAS III   400000.0
# 17103                 JULIE                           MOTAMEDI   350000.0

# %%
top_supporters.amount.plot.bar()

# %%
top_supporters.amount.plot.barh()

# %%
top_supporters.head(5).amount.plot.barh()

# %%
chart = top_supporters.head(5).amount.plot.barh()
chart.set_yticklabels(top_supporters.contributor_lastname)
# Out:
# [Text(0,0,u'STEYER'),
#  Text(0,0,u'STEYER'),
#  Text(0,0,u'PARKER AND AFFILIATED ENTITIES'),
#  Text(0,0,u'CORTOPASSI'),
#  Text(0,0,u'PARKER')]

# %%
top_supporters['contributor_fullname'] = top_supporters.contributor_firstname + " " + top_supporters.contributor_lastname

# %%
top_supporters.head(10)
# Out:
#       contributor_firstname            contributor_lastname      amount  \
# 33944             THOMAS F.                          STEYER  11400000.0
# 33885                THOMAS                          STEYER   8750000.0
# 31730                  SEAN  PARKER AND AFFILIATED ENTITIES   7250000.0
# 8208                DEAN A.                      CORTOPASSI   2000000.0
# 31729                  SEAN                          PARKER   1900000.0
# 26088              NICHOLAS                         MCKEOWN   1500000.0
# 16470                  JOAN                      CORTOPASSI   1500000.0
# 26089              NICHOLAS                        PRITZKER   1250000.0
# 6745                 DANIEL                           LEWIS   1250000.0
# 13221                 HENRY                   VAN AMERINGEN   1000000.0
#
#                       contributor_fullname
# 33944                     THOMAS F. STEYER
# 33885                        THOMAS STEYER
# 31730  SEAN PARKER AND AFFILIATED ENTITIES
# ...

# %%
chart = top_supporters.head(5).amount.plot.barh()
chart.set_yticklabels(top_supporters.contributor_fullname)
# Out:
# [Text(0,0,u'THOMAS F. STEYER'),
#  Text(0,0,u'THOMAS STEYER'),
#  Text(0,0,u'SEAN PARKER AND AFFILIATED ENTITIES'),
#  Text(0,0,u'DEAN A. CORTOPASSI'),
#  Text(0,0,u'SEAN PARKER')]

# %%
top_supporters.head(5).to_csv("top_supporters.csv")

# %%
def combine_names(row): 
    if row.contributor_fullname.startswith('SEAN PARKER'):
        return 'SEAN PARKER'
    return row.contributor_fullname

# %%
top_supporters.apply(combine_names, axis=1)
# Out:
# 33944       THOMAS F. STEYER
# 33885          THOMAS STEYER
# 31730            SEAN PARKER
# 8208      DEAN A. CORTOPASSI
# 31729            SEAN PARKER
# 26088       NICHOLAS MCKEOWN
# 16470        JOAN CORTOPASSI
# 26089      NICHOLAS PRITZKER
# 6745            DANIEL LEWIS
# 13221    HENRY VAN AMERINGEN
# dtype: object

# %%
top_supporters['contributor_cleanname'] = top_supporters.apply(combine_names, axis=1)

# %%
top_supporters.groupby(
"contributor_cleanname"
).amount.sum().reset_index().sort_values("amount", ascending=False).head(10)
# Out:
#   contributor_cleanname      amount
# 7      THOMAS F. STEYER  11400000.0
# 6           SEAN PARKER   9150000.0
# 8         THOMAS STEYER   8750000.0
# 1    DEAN A. CORTOPASSI   2000000.0
# 3       JOAN CORTOPASSI   1500000.0
# 4      NICHOLAS MCKEOWN   1500000.0
# 0          DANIEL LEWIS   1250000.0
# 5     NICHOLAS PRITZKER   1250000.0
# 2   HENRY VAN AMERINGEN   1000000.0
